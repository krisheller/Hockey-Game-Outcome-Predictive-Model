# %%
import requests
import json
import os
import pandas as pd 
import datetime as dt
import sqlite3
from pathlib import Path

# %%
Path('data\db.db').touch()
conn = sqlite3.connect('data\db.db')
c = conn.cursor()

# %%
games = pd.read_sql('SELECT id, date \
                    FROM games', con=conn)

games.shape[0]
# Out:
# 18969

# %%
games = pd.read_sql('SELECT * \
                    FROM games', con=conn)

games
# Out:
#        index          id  season        date  neutral_site  \
# 0          0  2008020554    2008  2009-01-01             1
# 1          0  2008020555    2008  2009-01-01             0
# 2          0  2008020556    2008  2009-01-01             0
# 3          0  2008020557    2008  2009-01-01             0
# 4          0  2008020558    2008  2009-01-01             0
# ...      ...         ...     ...         ...           ...
# 18964      0  2023020425    2023  2023-12-10             0
# 18965      0  2023020426    2023  2023-12-10             0
# 18966      0  2023020427    2023  2023-12-10             0
# 18967      0  2023020428    2023  2023-12-11             0
# 18968      0  2023020429    2023  2023-12-11             0
#
#                  start_time                   tz full_time home_team  \
# 0      2009-01-01T18:00:00Z      America/Chicago       REG       CHI
# 1      2009-01-02T00:00:00Z           US/Eastern       REG       BOS
# ...
